# %% [markdown]
# **Hipótesis**
# ------------
# Las hipótesis que os planteamos son:
#
# - ¿Es Australia el sitio más peligroso y letal para estar relajada en la playa?
#
# R= No, el más peligroso es USA pero Autralia no se queda atrás y es segundo país con más ataques.
#
# - ¿Hay diferencias entre los países en los ataques a hombres y mujeres?
#
# R= Si, como vimos en el pair programming de EDA III hay muchos más ataques a los hombres que a las mujeres en todos los países.
#
# - ¿Cuáles son las edades que más sufren ataques?
#
# R= El rango de edad que más sufre ataques es el de 21 años a 40 años.
#
# Independientemente de la edad, ¿sufren los hombres más ataques que las mujeres?
#
# R= Si, por mucho.
#
# - ¿En qué mes ocurren más ataques?
#
# R= En Julio, seguido muy de cerca Agosto.
#
# - ¿Cuál es la relación entre la especie y el tipo de ataque (si es fatal o no)?
#
# - R= La relación es:
#     - Grey: 29
#     - Lemon: 8
#     - Tiger: 153
#     - Undefined: 943
#     - White: 376
#
# Siendo el tiburón blanco más letal de los que se conocen.
#
# - ¿Cómo han evolucionado los ataques a lo largo del tiempo?
#
# R= Se han registrado más en los últimos años ya que hay más registros ahora que hace algunos años.

# %% [markdown]
# **Objetivos**
# -------
# Los objetivos de hoy son:
# - Haced una exploración inicial del dataframe:
# - ¿Cuál es el número de filas y columnas?
# - ¿Cuál es el porcentaje de valores nulos en cada columna? Presenta los resultados en un dataframe, donde las columnas sean el nombre de las variables y el porcentaje de nulos.
# - ¿Qué tipos de datos hay en cada columna?
# - Extraed la información general del dataframe.
# - Cread dos dataframes nuevos, uno que incluya solo las variables categóricas y otro que incluya solo las variables numéricas.
# - ¿Cuáles son los principales estádisticos de los dataframes?
# - Extraed los valores únicos su frecuencia. BONUS presenta los resultados en un dataframe. Os deberá quedar algo como esto:
#   - Donde variable es cada una de las variables categóricas que tenemos en el dataset y n_unicos es una lista con los nombres de los valores únicos de cada variable.

# %%
#Conclusiones:
    #1. HEmos inspeccionado los tipos de datos y en un futuro deberemos cambiar el tipo de algunas variables.
    #2. Deberemos c

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('datos/attack_limpio.csv',index_col=0)
df=df.drop(["unnamed:_0_x"], axis=1)

# %%
df.head(2)
# Out:
#     case_number    year        type     country      area location  \
# 0    1800.00.00  1800.0  Unprovoked  SEYCHELLES  St. Anne      NaN
# 1  1797.05.28.R  1797.0  Unprovoked         NaN       NaN      NaN
#
#                           activity   name  age time species_  \
# 0  a corsair's boat was overturned    NaN  NaN  NaN      NaN
# 1                Dropped overboard  child  NaN  NaN      NaN
#
#                                                 href  unnamed:_0_y  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...          6116
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...          6117
#
#                                      injury                  date  mes fatal_  \
# 0  FATAL, all onboard were killed by sharks                  1800  NaN      y
# 1                                     FATAL  Reported May-28-1797  May      y
#
#   sex2
# 0    F
# 1  NaN

# %%
df.tail(2)
# Out:
#        case_number    year        type country area location  \
# 6282  1802.04.13.R  1802.0  Unprovoked   INDIA  NaN      NaN
# 6283  1801.12.18.R  1801.0    Provoked     NaN  NaN      NaN
#
#                              activity              name  age time   species_  \
# 6282                              NaN               NaN  NaN  NaN        NaN
# 6283  Standing on landed shark's tail  Stephen Pettigew  NaN  NaN  12' shark
#
#                                                    href  unnamed:_0_y  \
# 6282  http://sharkattackfile.net/spreadsheets/pdf_di...          6114
# 6283  http://sharkattackfile.net/spreadsheets/pdf_di...          6115
#
#                         injury                  date  mes fatal_ sex2
# 6282                     FATAL  Reported Apr-13-1802  Apr      y  NaN
# 6283  FATAL, PROVOKED INCIDENT  Reported 18-Dec-1801  Dec      y    F

# %%
df.head()
# Out:
#     case_number    year        type     country             area  \
# 0    1800.00.00  1800.0  Unprovoked  SEYCHELLES         St. Anne
# 1  1797.05.28.R  1797.0  Unprovoked         NaN              NaN
# 2    1792.09.12  1792.0    Provoked     ENGLAND              NaN
# 3    1791.00.00  1791.0  Unprovoked   AUSTRALIA  New South Wales
# 4    1788.05.10  1788.0        Boat   AUSTRALIA  New South Wales
#
#               location                         activity  \
# 0                  NaN  a corsair's boat was overturned
# 1                  NaN                Dropped overboard
# 2  On the Thames River                          Fishing
# 3         Port Jackson                              NaN
# 4        Sydney Harbor                          Fishing
#
#                                name  age time species_  \
# 0                               NaN  NaN  NaN      NaN
# 1                             child  NaN  NaN      NaN
# 2                              male  NaN  NaN      NaN
# ...

# %%
print(f'Tenemos {df.shape[0]} filas y {df.shape[1]} columnas')
# Out:
# Tenemos 6284 filas y 18 columnas

# %%
#Hemos decidido dejar las variables como filas porque nos parecía más visual a la hora de interpretar los resultados.

#Time es la columna con más nulos,más de la mitad de sus valores. 

nulos=pd.DataFrame(df.isnull().sum()*100/df.shape[0])
nulos
# Out:
#                       0
# case_number    0.015913
# year           0.000000
# type           0.063654
# country        0.795672
# area           7.224698
# location       8.577339
# activity       8.625080
# name           3.325907
# age           44.875875
# time          53.150859
# species_      45.050923
# href           0.000000
# unnamed:_0_y   0.000000
# injury         0.445576
# date           0.000000
# mes            9.070656
# fatal_         9.659453
# sex2           8.975175

# %%
df.head(1)
# Out:
#   case_number    year        type     country      area location  \
# 0  1800.00.00  1800.0  Unprovoked  SEYCHELLES  St. Anne      NaN
#
#                           activity name  age time species_  \
# 0  a corsair's boat was overturned  NaN  NaN  NaN      NaN
#
#                                                 href  unnamed:_0_y  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...          6116
#
#                                      injury  date  mes fatal_ sex2
# 0  FATAL, all onboard were killed by sharks  1800  NaN      y    F

# %%
df.dtypes
# Out:
# case_number      object
# year            float64
# type             object
# country          object
# area             object
# location         object
# activity         object
# name             object
# age              object
# time             object
# species_         object
# href             object
# unnamed:_0_y      int64
# injury           object
# date             object
# mes              object
# fatal_           object
# sex2             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6284 entries, 0 to 6283
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   case_number   6283 non-null   object
#  1   year          6284 non-null   float64
#  2   type          6280 non-null   object
#  3   country       6234 non-null   object
#  4   area          5830 non-null   object
#  5   location      5745 non-null   object
#  6   activity      5742 non-null   object
#  7   name          6075 non-null   object
#  8   age           3464 non-null   object
#  9   time          2944 non-null   object
#  10  species_      3453 non-null   object
#  11  href          6284 non-null   object
#  12  unnamed:_0_y  6284 non-null   int64
#  13  injury        6256 non-null   object
#  14  date          6284 non-null   object
#  15  mes           5714 non-null   object
#  16  fatal_        5677 non-null   object
#  17  sex2          5720 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# case_number        1
# year               0
# type               4
# country           50
# area             454
# location         539
# activity         542
# name             209
# age             2820
# time            3340
# species_        2831
# href               0
# unnamed:_0_y       0
# injury            28
# date               0
# mes              570
# fatal_           607
# sex2             564
# dtype: int64

# %%
numericas=df.select_dtypes(include='number')
numericas

#Ahora nos devuelve solo una columna numérica porque debemos cambiar algunos tipos de columnas de object a int/float.
# Out:
#         year  unnamed:_0_y
# 0     1800.0          6116
# 1     1797.0          6117
# 2     1792.0          6118
# 3     1791.0          6119
# 4     1788.0          6120
# ...      ...           ...
# 6279  1804.0          6111
# 6280  1803.0          6112
# 6281  1803.0          6113
# 6282  1802.0          6114
# 6283  1801.0          6115
#
# [6284 rows x 2 columns]

# %%
categoricas=df.select_dtypes(include='object')
categoricas.head(2)

#Sobran columnas
# Out:
#     case_number        type     country      area location  \
# 0    1800.00.00  Unprovoked  SEYCHELLES  St. Anne      NaN
# 1  1797.05.28.R  Unprovoked         NaN       NaN      NaN
#
#                           activity   name  age time species_  \
# 0  a corsair's boat was overturned    NaN  NaN  NaN      NaN
# 1                Dropped overboard  child  NaN  NaN      NaN
#
#                                                 href  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                      injury                  date  mes fatal_  \
# 0  FATAL, all onboard were killed by sharks                  1800  NaN      y
# 1                                     FATAL  Reported May-28-1797  May      y
#
#   sex2
# 0    F
# 1  NaN

# %%
numericas.describe()
# Out:
#               year  unnamed:_0_y
# count  6284.000000   6284.000000
# mean   1927.164067   3142.505570
# std     281.458635   1814.287938
# min       0.000000      0.000000
# 25%    1942.000000   1571.750000
# 50%    1977.000000   3142.500000
# 75%    2005.000000   4713.250000
# max    2018.000000   6285.000000

# %%
categoricas.describe().T

#Podriamos hacerlo también con el siguiente código sin necesidad de crear otro DF -> df.describe(include=['0'])
# Out:
#             count unique                                                top  \
# case_number  6283   6283                                         1800.00.00
# type         6280      8                                         Unprovoked
# country      6234    212                                                USA
# area         5830    823                                            Florida
# location     5745   4102                   New Smyrna Beach, Volusia County
# activity     5742   1530                                            Surfing
# name         6075   5217                                               male
# age          3464    157                                                 17
# time         2944    366                                          Afternoon
# species_     3453   1547                                        White shark
# href         6284   6269  http://sharkattackfile.net/spreadsheets/pdf_di...
# ...

# %%
df.describe(include='all').T
# Out:
#                count unique  \
# case_number     6283   6283
# year          6284.0    NaN
# type            6280      8
# country         6234    212
# area            5830    823
# location        5745   4102
# activity        5742   1530
# name            6075   5217
# age             3464    157
# time            2944    366
# species_        3453   1547
# href            6284   6269
# unnamed:_0_y  6284.0    NaN
# injury          6256   3728
# date            6284   5429
# mes             5714     13
# fatal_          5677      2
# sex2            5720      2
#
#                                                             top  freq  \
# case_number                                          1800.00.00     1
# year                                                        NaN   NaN
# type                                                 Unprovoked  4584
# country                                                     USA  2222
# ...

# %% [markdown]
# **Conclusiones**
# ---------
# De qué nos sirven estos números y dataframe? Extraed conclusiones de ellos.
# Por ejemplo:
# - ¿Hay alguna columna que no tenga sentido su tipo de datos?
#
# R= Las columnas de case_number, age, time y date(datetime) creemos que no tienen sentido su tipo de datos y decidimos cambiarlas porque necesitamos operar con ellas.
#
# - ¿Hay alguna columna que no tenga sentido su nombre?
#
# R= Creemos que la columnas "href" no describe lo que contiene, por lo tanto no tiene sentido su nombre.
#
# - ¿Hay alguna columna que no tenga sentido su contenido?
#
# R= La columna "href" es una url lo cual es un contenido que no da fácil acceso a su información y no es descriptiva.
#
# - ¿Hay alguna columna que tenga demasiadas categorías o valores que nos pueda hacer difícil trabajar con ella?
#
# R= Si, "species_", "injury", "age" y "time"

# %%
df.to_csv('../EDA/datos/attack_eda1.csv')
