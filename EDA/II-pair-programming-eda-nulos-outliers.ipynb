# %%
import pandas as pd
import numpy as np
import sidetable

# %% [markdown]
# De todo esto, nos damos cuenta que solo tenemos que limpiar algunas de las columnas, en concreto age, species, country, fatal, year, sex. Reducimos esto a una tabla para saber qué tenemos ya limpito y qué no. Actualizamos esta tabla ya que en el ejercicio de pair de Limpieza I ya dejamos algunas columnas limpitas:

# %%
df=pd.read_csv('datos/attack_limpio.csv',index_col=0)
df.head(2)
# Out:
#     case_number  year     country  age time species_  mes fatal_ sex2
# 0    1800.00.00  1800  seychelles  NaN  NaN      NaN  NaN      y    F
# 1  1797.05.28.R  1797         NaN  NaN  NaN      NaN  May      y  NaN

# %% [markdown]
# ## Objetivos
# Usad la librería sidetable para:
# Explorar los valores nulos.

# %%
df.stb.missing()
# Out:
#              missing  total    percent
# time            3340   6284  53.150859
# species_        2831   6284  45.050923
# age             2820   6284  44.875875
# fatal_           607   6284   9.659453
# mes              570   6284   9.070656
# sex2             564   6284   8.975175
# country           50   6284   0.795672
# case_number        1   6284   0.015913
# year               0   6284   0.000000

# %% [markdown]
# Explorad la columna de country y reportad los resultados solo para aquellas categorías que incluyan el 70% de los datos.

# %%
df.stb.freq(["country"], thresh=70)
# Out:
# /home/yadi/anaconda3/lib/python3.9/site-packages/sidetable/sidetable.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results[results[other_label] == False].append(
#             country  count    percent  cumulative_count  cumulative_percent
# 0               usa   2222  35.643247              2222           35.643247
# 1         australia   1335  21.414822              3557           57.058069
# 2      south africa    577   9.255695              4134           66.313763
# 3  papua new guinea    134   2.149503              4268           68.463266
# 4            others   1966  31.536734              6234          100.000000

# %% [markdown]
# Explorad la columna country en relación al sexo, filtrando de nuevo por aquellas categorías que incluyan el 70% de los datos.

# %%
df.stb.freq(["country", "sex2"], thresh=70)
# Out:
# /home/yadi/anaconda3/lib/python3.9/site-packages/sidetable/sidetable.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results[results[other_label] == False].append(
#             country    sex2  count    percent  cumulative_count  \
# 0               usa       M   1788  31.512161              1788
# 1         australia       M   1105  19.474797              2893
# 2      south africa       M    487   8.583010              3380
# 3               usa       F    337   5.939373              3717
# 4  papua new guinea       M    109   1.921043              3826
# 5       new zealand       M    100   1.762425              3926
# 6            others  others   1748  30.807191              5674
#
#    cumulative_percent
# 0           31.512161
# 1           50.986958
# 2           59.569968
# 3           65.509341
# 4           67.430384
# 5           69.192809
# 6          100.000000

# %% [markdown]
# Haced los mismo para la columna activity en relación a la columna fatal. En este caso filtrad y mostrad los datos que incluyan el 60% de los datos.

# %% [markdown]
# 👀 Nota: No hemos utilizado la columna activity ya que en el pair anterior nos pedía eliminar las columnas que no necesitaramos para respondes las hipótesis

# %%
df.stb.freq(["country", "fatal_"], thresh=60)
# Out:
# /home/yadi/anaconda3/lib/python3.9/site-packages/sidetable/sidetable.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results[results[other_label] == False].append(
#         country  fatal_  count    percent  cumulative_count  \
# 0           usa       n   1832  32.516862              1832
# 1     australia       n    919  16.311679              2751
# 2  south africa       n    406   7.206248              3157
# 3        others  others   2477  43.965211              5634
#
#    cumulative_percent
# 0           32.516862
# 1           48.828541
# 2           56.034789
# 3          100.000000

# %% [markdown]
# Por último, realizad este análisis para la columna fecha (la que creamos en el último ejercicio de pair programming de Pandas) en relación a la columna fatal. Mostrad solo los resultados para las categorías que incluyan el 60% de los datos.

# %% [markdown]
# 🚨 Nota: Se ocupó la columna de "mes" ya que la columna de "fecha" la eliminamos en el pair anterior ya que nos lo pedía el ejercicio

# %%
df.stb.freq(["mes", "fatal_"], thresh=60)
# Out:
# /home/yadi/anaconda3/lib/python3.9/site-packages/sidetable/sidetable.py:151: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results = results[results[other_label] == False].append(
#       mes  fatal_  count    percent  cumulative_count  cumulative_percent
# 0     Jul       n    472   9.113729               472            9.113729
# 1     Aug       n    423   8.167600               895           17.281328
# 2     Sep       n    391   7.549720              1286           24.831048
# 3     Jun       n    347   6.700135              1633           31.531184
# 4     Jan       n    343   6.622900              1976           38.154084
# 5     Oct       n    333   6.429813              2309           44.583897
# 6     Apr       n    310   5.985712              2619           50.569608
# 7     Mar       n    290   5.599537              2909           56.169145
# ...

# %% [markdown]
# 📌 Nota Igual que siempre, no nos vale solo con picar el código, queremos que nos incluyais las conclusiones que extraeis.

# %% [markdown]
# - En relación a los nulos creemos que la columna "time" la eliminariamos ya que creemos que no da una información muy relevante y tenemos más de la mitad de nulos.
#     - Vero no eliminaría lo nulos porque se eliminarían la mitad de los datos del DataFrame.
#     - Yadi haría una prueba en una copia del DataFrame y eliminaría los nulos de la columna de "species_" y ve que tanta información pierdo de las demás columnas.
#
# Columna "country"
# - Concluímos que el mayor porcentaje de ataque ocurrió en USA y que el 70% de los datos se divide entre 4 países(USA, Australia, South Africa, Papua New Guinea).
#
# Columna "country" en relación al sexo
# - Concluímos que los Hombres reciben más ataques ya que cubren el 64% de los ataques mientras que las mujeres sólo cubren un 6% del 70%.
# - El 60% de los datos son ataques a hombres en sólo 3 países(USA, Australia, South Africa).
#
# Columna "country" en relacion a "fatal_"
# - El 60% de los ataques no han sido fatales y han ocurrido en los mismos 3 paises anteriores.
#
# Columna mes en relacion a "fatal_"
# - Concluimos que los ataques se suelen dar en el mes de Julio y Agosto con mayor frecuencia. Que corresponde que son los meses de temporada alta por vacaciones y suele haber más gente en las playas.

# %% [markdown]
# ## Conclusiones
#
# Si bien es cierto que la lección de hoy ha sido muy teórica, en esta parte los ejercicios no serán tanto de programar sino de pensar 🤔. ¿Qué tendréis que hacer?
#
# - En relación a los valores nulos:
#     - Identificar las columnas que tienen nulos (lo hicimos en el ejercicio de pair programming EDA I y en el de hoy con el sidetable).
#     - Debatid entre vosotras qué haríais con los valores nulos, ¿los quitaríais o los reemplazaríais con un valor que nosotras decidiremos?. Cread una celda de markdown en vuestro jupyter y escribid vuestras conclusiones.
#
#
# - En relación a los outliers, ya hemos ido conociendo un poco nuestro dataframe y de momento solo tenemos una columna de tipo numérico, por lo tanto, poco podemos hacer. Un poco más adelante, cuando hayamos hecho una serie de cambios sobre nuestras columnas podremos hacer una evaluación más profunda de estos.
